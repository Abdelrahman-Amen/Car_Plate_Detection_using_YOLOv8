# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UUR42GjF6pIV2zVkLJe8")
project = rf.workspace("carplate-1g9we").project("carplatedetection-u67lp")
dataset = project.version(4).download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 1.7 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.12.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.16)
# Collecting wget (from roboflow)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.41.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (2.0.12)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (4.8.0.74)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Downloading Pillow-8.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.3 MB/s eta 0:00:00
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=ecbf29b5c4500d4fee9369269f780e0f2431bc863df12cfb7f974f50a9c43bfa
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, Pillow, idna, cycler, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# Successfully installed Pillow-8.4.0 certifi-2022.12.7 cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.2 supervision-0.12.0 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# Downloading Dataset Version Zip in CarPlateDetection-4 to yolov8: 100% [69479334 / 69479334] bytes
# Extracting Dataset Version Zip to CarPlateDetection-4 in yolov8:: 100%|██████████| 3420/3420 [00:00<00:00, 4199.11it/s]

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
pwd
# Out:
# '/content'

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=25 imgsz=640

#!yolo task=detect mode=train model=yolov8n.pt imgsz=640 data=custom_data.yaml epochs=10 batch=8 name=yolov8n_custom
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to yolov8x.pt...
# 100% 131M/131M [00:00<00:00, 237MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8x.yaml, data=/content/CarPlateDetection-4/data.yaml, epochs=25, patience=50, batch=16, imgsz=640, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0010078125, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.4MB/s]
# 2023-07-29 16:43:13.430320: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-29 16:43:14.280610: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.Conv                  [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.Conv                  [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.C2f                   [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.Conv                  [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.C2f                   [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.Conv                  [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.C2f                   [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.Conv                  [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.C2f                   [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.SPPF                  [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.C2f                   [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.C2f                   [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.Conv                  [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.C2f                   [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.Conv                  [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.C2f                   [1280, 640, 3]
#  22        [15, 18, 21]  1   8718931  ultralytics.nn.modules.Detect                [1, [320, 640, 640]]
# Model summary: 365 layers, 68153571 parameters, 68153555 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0010078125), 103 bias
# train: Scanning /content/CarPlateDetection-4/train/labels... 1526 images, 0 backgrounds, 0 corrupt: 100% 1526/1526 [00:00<00:00, 2444.58it/s]
# train: New cache created: /content/CarPlateDetection-4/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/CarPlateDetection-4/valid/labels... 118 images, 0 backgrounds, 0 corrupt: 100% 118/118 [00:00<00:00, 2197.72it/s]
# val: New cache created: /content/CarPlateDetection-4/valid/labels.cache
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      13.4G      1.069      1.681      1.054         15        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:05<00:00,  1.29s/it]
#                    all        118        124      0.945      0.965      0.984      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      15.4G     0.9823     0.7479     0.9687          8        640: 100% 96/96 [01:49<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.00s/it]
#                    all        118        124      0.941      0.935      0.963      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      15.4G      1.083     0.9024     0.9911         15        640: 100% 96/96 [01:52<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124      0.975      0.943      0.959      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      15.4G      1.115     0.8411      1.011          9        640: 100% 96/96 [01:52<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124      0.941      0.911      0.969      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      15.4G      1.151      0.863       1.04         16        640: 100% 96/96 [01:52<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.02s/it]
#                    all        118        124      0.961      0.935      0.966      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      15.4G      1.114     0.7974      1.026         10        640: 100% 96/96 [01:52<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124      0.951      0.919      0.971      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      15.4G      1.105     0.7982       1.03          4        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124      0.976      0.919      0.963      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      15.4G      1.088     0.7174      1.021         14        640: 100% 96/96 [01:52<00:00,  1.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.03s/it]
#                    all        118        124      0.991      0.933      0.977       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      15.4G      1.034     0.6948     0.9902          6        640: 100% 96/96 [01:52<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124      0.958      0.968      0.978      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      15.4G      1.028     0.6815     0.9934         16        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.02s/it]
#                    all        118        124      0.971      0.944      0.981      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      15.4G     0.9738       0.63     0.9823         15        640: 100% 96/96 [01:52<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124      0.981      0.935      0.984      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      15.4G     0.9774     0.6233      0.976         13        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.07s/it]
#                    all        118        124       0.98      0.968      0.992      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      15.4G     0.9631     0.5915     0.9679         15        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.05s/it]
#                    all        118        124      0.973      0.944      0.978      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      15.4G     0.9139     0.5638     0.9567         15        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.04s/it]
#                    all        118        124      0.966      0.992      0.994      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      15.4G     0.9141     0.5697     0.9526         17        640: 100% 96/96 [01:51<00:00,  1.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.04s/it]
#                    all        118        124      0.965      0.968      0.991      0.802
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      15.4G     0.8672     0.5065     0.9776          6        640: 100% 96/96 [01:50<00:00,  1.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.06s/it]
#                    all        118        124      0.983       0.94      0.985        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      15.4G     0.8442     0.4869     0.9578          6        640: 100% 96/96 [01:49<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.08s/it]
#                    all        118        124      0.968      0.974      0.993      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      15.4G     0.8221     0.4625     0.9622          6        640: 100% 96/96 [01:49<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.08s/it]
#                    all        118        124      0.984      0.975      0.994      0.812
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      15.4G     0.7871     0.4478     0.9542          6        640: 100% 96/96 [01:49<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.02s/it]
#                    all        118        124      0.953      0.977      0.993      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      15.4G     0.7848     0.4434     0.9555          6        640: 100% 96/96 [01:47<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.02s/it]
#                    all        118        124      0.984      0.981      0.994      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      15.4G     0.7566     0.4301      0.931          7        640: 100% 96/96 [01:48<00:00,  1.13s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.01s/it]
#                    all        118        124       0.97      0.984      0.994      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      15.4G     0.7373      0.397     0.9238          6        640: 100% 96/96 [01:47<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.12s/it]
#                    all        118        124      0.954      0.976      0.993      0.833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      15.4G     0.7088     0.3843     0.9134          6        640: 100% 96/96 [01:47<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.03s/it]
#                    all        118        124      0.976      0.983      0.994      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      15.4G     0.6792     0.3649     0.9009          6        640: 100% 96/96 [01:47<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.05s/it]
#                    all        118        124      0.992      0.975      0.994      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      15.4G     0.6613     0.3439     0.8929          6        640: 100% 96/96 [01:47<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:06<00:00,  1.53s/it]
#                    all        118        124      0.992      0.976      0.994      0.854
#
# 25 epochs completed in 0.853 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 136.7MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 136.7MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:06<00:00,  1.56s/it]
#                    all        118        124      0.992      0.976      0.994      0.853
# Speed: 2.4ms pre-process, 25.1ms inference, 0.0ms loss, 3.7ms post-process per image
# Results saved to runs/detect/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    val_batch0_labels.jpg
# confusion_matrix.png				    val_batch0_pred.jpg
# events.out.tfevents.1690648997.c33df42c8c8b.1320.0  val_batch1_labels.jpg
# F1_curve.png					    val_batch1_pred.jpg
# P_curve.png					    val_batch2_labels.jpg
# PR_curve.png					    val_batch2_pred.jpg
# R_curve.png					    weights
# results.csv

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_labels.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# 2023-07-29 17:37:56.284442: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-29 17:37:57.154068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/CarPlateDetection-4/valid/labels.cache... 118 images, 0 backgrounds, 0 corrupt: 100% 118/118 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:07<00:00,  1.04it/s]
#                    all        118        124      0.991      0.976      0.994      0.851
# Speed: 0.2ms pre-process, 56.2ms inference, 0.0ms loss, 1.7ms post-process per image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# 2023-07-29 17:38:14.496152: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-29 17:38:15.335703: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/60 /content/CarPlateDetection-4/test/images/306db6d3-imagem-abre_jpeg_jpg.rf.aec4d685766fb9ab65e5703962ed2fae.jpg: 640x640 1 car_plate, 71.7ms
# image 2/60 /content/CarPlateDetection-4/test/images/DCAM0006_JPG_jpg.rf.418a987ef9ba590a0e2d05c938b71fa9.jpg: 640x640 1 car_plate, 59.5ms
# image 3/60 /content/CarPlateDetection-4/test/images/DCAM0006_JPG_jpg.rf.7a5963a855de1948d8022f76edb1893c.jpg: 640x640 1 car_plate, 59.5ms
# image 4/60 /content/CarPlateDetection-4/test/images/DCAM0012_JPG_jpg.rf.175a4d20ccb432cd7c19d7eff46374e3.jpg: 640x640 1 car_plate, 59.5ms
# image 5/60 /content/CarPlateDetection-4/test/images/DCAM0012_JPG_jpg.rf.f548e3dc344798a36d4c476b4e59204a.jpg: 640x640 1 car_plate, 51.3ms
# image 6/60 /content/CarPlateDetection-4/test/images/DCAM0014_JPG_jpg.rf.8768a5f4ab7a17f46c7c24d98287ae90.jpg: 640x640 1 car_plate, 51.8ms
# image 7/60 /content/CarPlateDetection-4/test/images/DCAM0018_JPG_jpg.rf.e1fdfcdd9a229e79eda6e4d9795f3f99.jpg: 640x640 1 car_plate, 51.5ms
# image 8/60 /content/CarPlateDetection-4/test/images/DCAM0019_JPG_jpg.rf.08f42f7bb600484062d6fa5f70aa622c.jpg: 640x640 1 car_plate, 51.3ms
# image 9/60 /content/CarPlateDetection-4/test/images/DCAM0026_JPG_jpg.rf.8805b3c15ce87e06dad38e0778e198a0.jpg: 640x640 1 car_plate, 51.8ms
# image 10/60 /content/CarPlateDetection-4/test/images/DCAM0030_JPG_jpg.rf.8797fae8e935a5316d609ac448cd5736.jpg: 640x640 1 car_plate, 51.9ms
# image 11/60 /content/CarPlateDetection-4/test/images/DCAM0030_JPG_jpg.rf.8888dc887ae2261331e670dc39830bd8.jpg: 640x640 2 car_plates, 51.9ms
# image 12/60 /content/CarPlateDetection-4/test/images/DCAM0031_JPG_jpg.rf.9f3e4234da71e6b49f9363564657f06e.jpg: 640x640 1 car_plate, 51.9ms
# image 13/60 /content/CarPlateDetection-4/test/images/DCAM0033_JPG_jpg.rf.00c809f8167848d57ef888b4b8a44de4.jpg: 640x640 1 car_plate, 51.3ms
# image 14/60 /content/CarPlateDetection-4/test/images/DCAM0033_JPG_jpg.rf.e5639782e881216305c043ae0e25ff7e.jpg: 640x640 1 car_plate, 51.1ms
# image 15/60 /content/CarPlateDetection-4/test/images/DCAM0037_JPG_jpg.rf.13aa6c2cf1dfc8f441e7f192626dc6b1.jpg: 640x640 2 car_plates, 52.8ms
# image 16/60 /content/CarPlateDetection-4/test/images/DCAM0039_JPG_jpg.rf.036649670c8c00c8d9522731f342875e.jpg: 640x640 1 car_plate, 50.9ms
# image 17/60 /content/CarPlateDetection-4/test/images/DCAM0041_JPG_jpg.rf.ce2e405a46c8c481ed486774fa95aca7.jpg: 640x640 1 car_plate, 52.0ms
# image 18/60 /content/CarPlateDetection-4/test/images/DCAM0046_JPG_jpg.rf.bf82d1b88f2228a721dda3715866e72b.jpg: 640x640 1 car_plate, 52.6ms
# image 19/60 /content/CarPlateDetection-4/test/images/DCAM0046_JPG_jpg.rf.df904a3ff769c3e57c2580e310759eac.jpg: 640x640 1 car_plate, 50.6ms
# image 20/60 /content/CarPlateDetection-4/test/images/DCAM0047_JPG_jpg.rf.0ea03f71f1989ee40c7806d0d4f97603.jpg: 640x640 1 car_plate, 52.1ms
# image 21/60 /content/CarPlateDetection-4/test/images/DCAM0053_JPG_jpg.rf.1568308d112c9211f0df8ddf4568f898.jpg: 640x640 1 car_plate, 52.4ms
# image 22/60 /content/CarPlateDetection-4/test/images/DCAM0054_JPG_jpg.rf.e4700a633219dfa2df8632f4d5ae7997.jpg: 640x640 1 car_plate, 51.4ms
# image 23/60 /content/CarPlateDetection-4/test/images/DCAM0056_JPG_jpg.rf.5b1748e73980d0dcd1ac01d210b1a608.jpg: 640x640 2 car_plates, 51.5ms
# image 24/60 /content/CarPlateDetection-4/test/images/DCAM0060_JPG_jpg.rf.6f7513910908026af8628a42c5453066.jpg: 640x640 1 car_plate, 51.8ms
# image 25/60 /content/CarPlateDetection-4/test/images/DCAM0062_JPG_jpg.rf.28f7f92e59b25ba3d615f55eaba187f0.jpg: 640x640 1 car_plate, 52.1ms
# image 26/60 /content/CarPlateDetection-4/test/images/DCAM0063_JPG_jpg.rf.a87eb0b4d39994d6680062eb69955650.jpg: 640x640 1 car_plate, 51.5ms
# image 27/60 /content/CarPlateDetection-4/test/images/DCAM0074_JPG.rf.7275266a3de6d099a4e2e84fc6233af2.jpg: 640x640 1 car_plate, 51.3ms
# image 28/60 /content/CarPlateDetection-4/test/images/DCAM0079_JPG_jpg.rf.7febceeb17eb78e0c7c0fd961a8487bf.jpg: 640x640 1 car_plate, 51.2ms
# image 29/60 /content/CarPlateDetection-4/test/images/DCAM0085_JPG_jpg.rf.afc1448eaac8255e6ee0bca5c4315111.jpg: 640x640 1 car_plate, 52.0ms
# image 30/60 /content/CarPlateDetection-4/test/images/DCAM0086_JPG_jpg.rf.995c4d505fd8865c19aca3615e4136de.jpg: 640x640 1 car_plate, 51.2ms
# image 31/60 /content/CarPlateDetection-4/test/images/DCAM0088_JPG_jpg.rf.00eef697d0089fd2cf20c7620294fba8.jpg: 640x640 1 car_plate, 51.6ms
# image 32/60 /content/CarPlateDetection-4/test/images/DCAM0088_JPG_jpg.rf.ec794dfaed037dc8ed01c57982f3f5a1.jpg: 640x640 1 car_plate, 52.3ms
# image 33/60 /content/CarPlateDetection-4/test/images/DCAM0091_JPG_jpg.rf.a8846cc3250c5a85adb432a175aa0103.jpg: 640x640 1 car_plate, 51.9ms
# image 34/60 /content/CarPlateDetection-4/test/images/DCAM0094_JPG_jpg.rf.b0cc7448e1e774be330dbdee82fe53d1.jpg: 640x640 2 car_plates, 52.4ms
# image 35/60 /content/CarPlateDetection-4/test/images/DCAM0098_JPG_jpg.rf.c428fbd2f6be56394a3c90b0aee3a1a2.jpg: 640x640 1 car_plate, 52.0ms
# image 36/60 /content/CarPlateDetection-4/test/images/DCAM0099_JPG_jpg.rf.301bdccb5af65ae03d9e15ab82e9f57a.jpg: 640x640 1 car_plate, 51.1ms
# image 37/60 /content/CarPlateDetection-4/test/images/NZW2197_jpg.rf.ea72995173eebad4dc93aefafc408357.jpg: 640x640 1 car_plate, 52.2ms
# image 38/60 /content/CarPlateDetection-4/test/images/images-1-_png_jpg.rf.7517911b0c9faf2e0ed6a965343e6e39.jpg: 640x640 1 car_plate, 51.7ms
# image 39/60 /content/CarPlateDetection-4/test/images/images160_jpg.rf.2919b86fdfb75611ae5204bdd117e227.jpg: 640x640 1 car_plate, 52.1ms
# image 40/60 /content/CarPlateDetection-4/test/images/images80_jpg.rf.70551970188f7882190eb430afc7bfa7.jpg: 640x640 1 car_plate, 51.3ms
# image 41/60 /content/CarPlateDetection-4/test/images/track0015-01-_png_jpg.rf.7a4daf7d80fc3bf9a71b0dde82505da7.jpg: 640x640 1 car_plate, 50.8ms
# image 42/60 /content/CarPlateDetection-4/test/images/track0028-01-_png_jpg.rf.e24b14722060f57e3b94384e59d56570.jpg: 640x640 50.8ms
# image 43/60 /content/CarPlateDetection-4/test/images/track0032-01-_png_jpg.rf.f6f7ac274e7fa2a66e302045bcdf961b.jpg: 640x640 1 car_plate, 52.2ms
# image 44/60 /content/CarPlateDetection-4/test/images/track0036-01-_png_jpg.rf.229b7d2a6f1b853e415fd06283c3abaf.jpg: 640x640 1 car_plate, 51.7ms
# image 45/60 /content/CarPlateDetection-4/test/images/track0068-01-_png_jpg.rf.99e40f5ca9c81b28f530c6c7e876200a.jpg: 640x640 1 car_plate, 51.9ms
# image 46/60 /content/CarPlateDetection-4/test/images/track0070-01-_png_jpg.rf.00ae6426d1db1aad13f18b71d3b30146.jpg: 640x640 1 car_plate, 51.6ms
# image 47/60 /content/CarPlateDetection-4/test/images/track0072-01-_png_jpg.rf.d21ee37d3b9d96206ffb7a5ddbc4af78.jpg: 640x640 1 car_plate, 51.5ms
# image 48/60 /content/CarPlateDetection-4/test/images/track0083-01-_png_jpg.rf.585215f31bca93221e3b768e98e7dd10.jpg: 640x640 1 car_plate, 52.2ms
# image 49/60 /content/CarPlateDetection-4/test/images/track0084-01-_png_jpg.rf.5a183b1f2a89cf6046ed6dd5a7414c72.jpg: 640x640 1 car_plate, 50.1ms
# image 50/60 /content/CarPlateDetection-4/test/images/track0089-01-_png_jpg.rf.675d7fab842a1dec878109f5a1e9ae97.jpg: 640x640 1 car_plate, 52.3ms
# image 51/60 /content/CarPlateDetection-4/test/images/track0097-01-_png_jpg.rf.090befd6630501f8d548ba26cc31548e.jpg: 640x640 1 car_plate, 51.8ms
# image 52/60 /content/CarPlateDetection-4/test/images/track0111-01-_png_jpg.rf.8b7527f529b2cf30153ae920938ecd12.jpg: 640x640 1 car_plate, 52.1ms
# image 53/60 /content/CarPlateDetection-4/test/images/track0121-01-_png_jpg.rf.9585085d0de3a01c4295d6223a335379.jpg: 640x640 1 car_plate, 52.1ms
# image 54/60 /content/CarPlateDetection-4/test/images/track0126-01-_png_jpg.rf.c856a33571bf03962832b9ecfd9e4fe1.jpg: 640x640 1 car_plate, 51.2ms
# image 55/60 /content/CarPlateDetection-4/test/images/track0127-01-_png_jpg.rf.7d32917f48a13f1344ca435a91b3d24f.jpg: 640x640 1 car_plate, 51.0ms
# image 56/60 /content/CarPlateDetection-4/test/images/track0129-01-_png_jpg.rf.4b83aaf8606418a920d90aefce63b887.jpg: 640x640 51.6ms
# image 57/60 /content/CarPlateDetection-4/test/images/track0136-01-_png_jpg.rf.5918bbe0e2e9dcd44466772960e6788e.jpg: 640x640 1 car_plate, 51.5ms
# image 58/60 /content/CarPlateDetection-4/test/images/track0146-01-_png_jpg.rf.9b104dee013cf14c0a21f6521132edab.jpg: 640x640 1 car_plate, 52.2ms
# image 59/60 /content/CarPlateDetection-4/test/images/track0149-01-_png_jpg.rf.76b94f07f2b7700a67f25f08b6fcc1ec.jpg: 640x640 1 car_plate, 51.4ms
# image 60/60 /content/CarPlateDetection-4/test/images/track0150-01-_png_jpg.rf.60579f0b595efae199214e4d3dfa8e30.jpg: 640x640 1 car_plate, 52.1ms
# Speed: 0.5ms pre-process, 52.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:5]:
      display(Image(filename=image_path, width=600))
      print("\n")
